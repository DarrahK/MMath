# %% [markdown]
# Plot for demostrating how we can use parametric models to model data.
#
# Sources:
#
# [Python - Normal Distribution](https://www.tutorialspoint.com/python_data_science/python_normal_distribution.htm#:~:text=The%20normal%20distribution%20is%20a,value%20making%20the%20arrangement%20symmetric.&text=Histograms%20are%20created%20over%20which%20we%20plot%20the%20probability%20distribution%20curve.)
#
# **NOTE**: This code is just for experimentation/explanation purposes for my thesis only and is not intended to be a demonstration of my coding ability.

# %%
import matplotlib.pyplot as plt
import numpy as np

sigma = 0.1
mu = 0.5
s = np.random.normal(mu, sigma, 1000)

# Create the bins and histogram
count, bins, ignored = plt.hist(s, 20, density = True)

# Plot the distribution curves
mu = 0.4
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
    np.exp( - (bins - mu)**2 / (2 * sigma**2) ), linewidth=3, label = 'θ = 0.4')

mu = 0.5
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
    np.exp( - (bins - mu)**2 / (2 * sigma**2) ), linewidth=3, color = "y", label = 'θ = 0.5')

mu = 0.6
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
    np.exp( - (bins - mu)**2 / (2 * sigma**2) ), linewidth=3, label = 'θ = 0.6')

plt.legend()
plt.title("Fitting the parametric model pθ(x) = N(θ, 0.1) to N(0.5, 0.1)")
plt.show()
